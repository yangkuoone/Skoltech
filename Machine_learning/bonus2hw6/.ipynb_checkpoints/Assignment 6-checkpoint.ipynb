# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools as it

from matplotlib import cm
from sklearn.preprocessing import scale
from sklearn.linear_model import LinearRegression 
from sklearn.decomposition import PCA
from sklearn.manifold import LocallyLinearEmbedding
from sklearn.manifold import MDS
from sklearn.manifold import SpectralEmbedding
from sklearn.manifold import TSNE
from sklearn.linear_model import LassoCV, LassoLarsCV, LassoLarsIC
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from statsmodels.regression.linear_model import OLS
from statsmodels.regression.linear_model import RegressionResults
from sklearn.metrics import r2_score

# %matplotlib inline

# %% [markdown]
# ## Assignment 6: model selection and manifold learning
#
# ### Exercise 1
# * Load the data set from file prostate.csv
# * Carry out a best-subset linear regression analysis.
# * Compute the AIC, BIC, five- and tenfold cross-validation estimates of prediction error
# * Make conclusion
#
# Prostate data info:
#
# Predictors:
# * lcavol
# * lweight
# * age
# * lbph
# * svi
# * lcp
# * gleason
# * pgg45
#
# outcome:
# * lpsa

# %% [markdown]
# #### Reading the data
# ##### without scaling

# %%
# data = pd.read_csv('prostate.csv')
# columns = list(data.columns)
# n_samples = data.shape[0]
# X, y = np.asarray(data)[:, :-1], np.asarray(data)[:, -1]

# data

# %% [markdown]
# ##### with scaling

# %%
df = pd.read_csv(open("prostate.csv"))
col = list(df.columns)

#scaling the data
df = scale(df)
data = pd.DataFrame(df, columns=col)

X, y = np.asarray(data)[:, :-1], np.asarray(data)[:, -1]

data
# Out:
#       lcavol   lweight       age      lbph       svi       lcp   gleason  \
# 0  -1.645861 -2.016634 -1.872101 -1.030029 -0.525657 -0.867655 -1.047571
# 1  -1.999313 -0.725759 -0.791989 -1.030029 -0.525657 -0.867655 -1.047571
# 2  -1.587021 -2.200154  1.368234 -1.030029 -0.525657 -0.867655  0.344407
# 3  -2.178174 -0.812191 -0.791989 -1.030029 -0.525657 -0.867655 -1.047571
# 4  -0.510513 -0.461218 -0.251933 -1.030029 -0.525657 -0.867655 -1.047571
# 5  -2.046706 -0.938806 -1.872101 -1.030029 -0.525657 -0.867655 -1.047571
# 6  -0.522668 -0.364678  0.018095  0.356701 -0.525657 -0.867655 -1.047571
# 7  -0.560208 -0.209841 -0.791989  0.995291 -0.525657 -0.867655 -1.047571
# 8  -1.813627 -0.209841 -2.277143 -1.030029 -0.525657 -0.867655 -1.047571
# 9  -0.961052 -0.901927 -0.116919 -1.030029 -0.525657 -0.867655 -1.047571
# 10 -0.934188 -0.058200  0.153109 -1.030029 -0.525657 -0.867655 -1.047571
# 11 -2.300218 -0.071004 -0.116919  0.808276 -0.525657 -0.867655 -1.047571
# 12  0.224659 -1.422069 -0.116919 -1.030029 -0.525657 -0.300837  0.344407
# 13  0.108346 -1.479863  0.423137 -1.030029 -0.525657 -0.867655  0.344407
# 14 -0.122844 -0.438585 -0.927003 -1.030029 -0.525657 -0.180743  0.344407
# 15  0.163023 -1.332460  0.288123 -1.030029 -0.525657 -0.867655 -1.047571
# 16 -1.505735 -0.264970  0.828178  0.792484 -0.525657 -0.300837  0.344407
# 17  0.800383  0.047904  0.288123 -1.030029 -0.525657  0.396060 -1.047571
# 18 -1.630766 -0.847675 -3.087227 -1.030029 -0.525657 -0.867655 -1.047571
# 91  1.008835  0.114086 -0.386947  0.864484  1.902379 -0.867655  0.344407
# 92  1.262444  0.580608  0.558151 -1.030029  1.902379  1.079149  0.344407
# 93  2.107397  0.628738 -2.682185 -1.030029  1.902379  1.688267  0.344407
# 94  1.328267 -0.546127 -1.602073 -1.030029  1.902379  1.900197  0.344407
# 95  1.307045  0.340141  0.558151  1.010033  1.902379  1.249088  0.344407
# 96  1.809719  0.811961  0.558151  0.234114  1.902379  2.216735  0.344407
#
#        pgg45      lpsa
# 0  -0.868957 -2.533318
# 1  -0.868957 -2.299712
# 2  -0.156155 -2.299712
# 3  -0.868957 -2.299712
# 4  -0.868957 -1.834631
# 5  -0.868957 -1.491617
# 6  -0.868957 -1.491617
# 7  -0.868957 -1.414162
# 8  -0.868957 -1.246180
# 9  -0.868957 -1.246180
# 10 -0.868957 -1.054927
# 11 -0.868957 -1.054927
# 12  0.200246 -1.054927
# 13 -0.690757 -0.984282
# 14 -0.690757 -0.940181
# 15 -0.868957 -0.898207
# 16  0.200246 -0.877955
# 17 -0.868957 -0.858163
# 18 -0.868957 -0.801351
# 19 -0.868957 -0.765436
# 20 -0.868957 -0.730945
# 21 -0.156155 -0.714198
# 22 -0.868957 -0.681641
# 23  1.269449 -0.665807
# 24 -0.868957 -0.650257
# 25 -0.868957 -0.619965
# 26  1.625850 -0.590692
# 27 -0.156155 -0.576416
# 28  1.982251 -0.548548
# 29 -0.868957 -0.508349
# ..       ...       ...
# 67 -0.512556  0.421735
# 68 -0.868957  0.421735
# 69 -0.690757  0.430690
# 70  1.269449  0.465614
# 71  0.022045  0.486751
# 72 -0.156155  0.503299
# 73  2.338652  0.519538
# 74 -0.156155  0.693917
# 75  0.913048  0.748161
# 76  1.269449  0.796300
# 77 -0.512556  0.833544
# 78  1.625850  0.852958
# 79  0.913048  0.900978
# 80  0.556647  0.903569
# 81  1.269449  0.916413
# 82  0.200246  0.946487
# 83  1.625850  0.951400
# 84  0.200246  0.965975
# 85  1.269449  1.003688
# 86 -0.868957  1.046449
# 87  0.200246  1.074542
# 88  1.269449  1.311394
# 89  1.804051  1.319457
# 90 -0.868957  1.350983
# 91 -0.334356  1.437841
# 92  1.269449  1.660415
# 93  0.556647  1.921044
# 94 -0.512556  2.320465
# 95  1.982251  2.611649
# 96 -0.156155  2.703452
#
# [97 rows x 9 columns]

# %% [markdown]
# #### Generating all combinations

# %%
combinations = []
for k in range(1, 9):
    comb = np.array(list(it.combinations(columns[:-1], k)))
    combinations.append(comb)


all_combinations = []
for i in range(len(combinations)):
    all_combinations += combinations[i].tolist()
all_combinations = np.array(all_combinations)

num_combinations = len(all_combinations)
print('num of combinations', num_combinations)
# Out:
# num of combinations 255

# %% [markdown]
# #### All scores

# %%
aic_scores, bic_scores, fivefold, tenfold = [], [], [], []
for i in range(num_combinations):
    combination = all_combinations[i]
    X = np.asarray(data[combination])
    LS = OLS(y, X)
    regression = LS.fit()
    aic_scores.append(regression.aic)
    bic_scores.append(regression.bic)
    fivefold.append(cross_val_score(LinearRegression(), X, y, scoring='neg_mean_squared_error', cv=5).mean())
    tenfold.append(cross_val_score(LinearRegression(), X, y, scoring='neg_mean_squared_error', cv=10).mean())

# %% [markdown]
# #### Result

# %%
print('------------Best-subset solution for different scores------------')
print('AIC:', all_combinations[np.argmin(np.abs(aic_scores))], 'Score', aic_scores[np.argmin(np.abs(aic_scores))])
print('BIC:', all_combinations[np.argmin(np.abs(bic_scores))], 'Score', bic_scores[np.argmin(np.abs(bic_scores))])
print('Fivefold CV:', all_combinations[np.argmax(fivefold)], 'Score', np.max(fivefold))
print('Tenfold CV:', all_combinations[np.argmax(tenfold)], 'Score', np.max(tenfold))
# Out:
# ------------Best-subset solution for different scores------------
# AIC: ['lcavol', 'lweight', 'age', 'lbph', 'svi'] Score 182.713892633
# BIC: ['lcavol', 'lweight', 'svi'] Score 190.983221133
# Fivefold CV: ['lcavol', 'lweight', 'age', 'pgg45'] Score -0.667301846503
# Tenfold CV: ['lcavol', 'lweight', 'age', 'pgg45'] Score -0.545295089749

# %% [markdown]
# ### Exercise 2
# * Apply dimensionality reduction, try PCA, LLE, MDS, Laplacian Eigenmaps and t-SNE. Visualize data set.
# * What can you say about clusters in the dataset?
# * Build linear regression models using output produced by for different dimensionalities. Compute quality of the models.
# * Make conclusion.

# %% [markdown]
# #### PCA

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
color_labels = y
colors = [cm.Vega10((y_) / max(color_labels)) for y_ in color_labels]

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=colors, s = 30)
plt.xlabel('x0')
plt.ylabel('x1')
plt.title('PCA visualisation')

# %%
LS = OLS(y, X_pca)
regression_pca = LS.fit()
print('-----Scores2D-----')
print('AIC =', regression_pca.aic)
print('BIC =', regression_pca.bic)
# Out:
# -----Scores2D-----
# AIC = 216.449256297
# BIC = 221.598678254

# %% [markdown]
# #### LLE

# %%
lle = LocallyLinearEmbedding(n_components=2)
X_lle = lle.fit_transform(X)

# %%
color_labels = data['lcavol']
colors = [cm.Vega10((y_) / max(color_labels)) for y_ in color_labels]

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X_lle[:, 0], X_lle[:, 1], c=colors, s = 30)
plt.xlabel('x0')
plt.ylabel('x1')
plt.title('LLE visualisation')

# %%
LS = OLS(y, X_lle)
regression_lle = LS.fit()
print('-----Scores-----')
print('AIC =', regression_lle.aic)
print('BIC =', regression_lle.bic)
# Out:
# -----Scores-----
# AIC = 262.31155864
# BIC = 267.460980597

# %% [markdown]
# #### MDS

# %%
mds = MDS(n_components=2)
X_mds = mds.fit_transform(X)

# %%
color_labels = data['lcavol']
colors = [cm.Vega10((y_) / max(color_labels)) for y_ in color_labels]

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X_mds[:, 0], X_mds[:, 1], c=colors, s = 30)
plt.xlabel('x0')
plt.ylabel('x1')
plt.title('MDS visualisation')

# %%
LS = OLS(y, X_mds)
regression_mds = LS.fit()
print('-----Scores-----')
print('AIC =', regression_mds.aic)
print('BIC =', regression_mds.bic)
# Out:
# -----Scores-----
# AIC = 217.726245378
# BIC = 222.875667335

# %% [markdown]
# #### Laplacian Eigenmaps (Spectral Embedding)

# %%
se = SpectralEmbedding(n_components=2)
X_se = se.fit_transform(X)

# %%
color_labels = data['lcavol']
colors = [cm.Vega10((y_) / max(color_labels)) for y_ in color_labels]

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X_se[:, 0], X_se[:, 1], c=colors, s = 30)
plt.xlabel('x0')
plt.ylabel('x1')
plt.title('Laplacian Eigenmaps visualisation')

# %%
LS = OLS(y, X_se)
regression_se = LS.fit()
print('-----Scores-----')
print('AIC =', regression_se.aic)
print('BIC =', regression_se.bic)
# Out:
# -----Scores-----
# AIC = 215.719686343
# BIC = 220.8691083

# %% [markdown]
# #### t-SNE

# %%
tsne = TSNE(n_components=2, )
X_tsne = tsne.fit_transform(X)

# %%
color_labels = data['lweight']
colors = [cm.Vega10((y_) / max(color_labels)) for y_ in color_labels]

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=colors, s = 30)
plt.xlabel('x0')
plt.ylabel('x1')
plt.title('t-SNE visualisation')

# %%
LS = OLS(y, X_tsne)
regression_tsne = LS.fit()
print('-----Scores-----')
print('AIC =', regression_tsne.aic)
print('BIC =', regression_tsne.bic)
# Out:
# -----Scores-----
# AIC = 268.932595328
# BIC = 274.082017285

# %%
print ('Is NAN?', np.isnan(X).any())
print ('Is INF?', np.isinf(X).any())
# Out:
# Is NAN? False
# Is INF? False

# %% [markdown]
# #### Results

# %%
dimensions = [2, 3, 4, 5]

methods = [PCA, LocallyLinearEmbedding, MDS, SpectralEmbedding, TSNE]

col = ['AIC', 'BIC']

ind = []

df = pd.DataFrame(columns=col, index=ind)
for method in methods:
    for dim in dimensions:
        X_tr = method(n_components=dim).fit_transform(X)
        LS = OLS(y, X_tr)
        regression_tr = LS.fit()
        aic, bic = regression_tr.aic, regression_tr.bic
        ind = str(method)[:-2].split('.')[-1] + ' ' + ('dim=%s' % dim)
        df1 = pd.DataFrame(columns=col, 
                           index=[ind])
        df1.loc[ind] = [aic, bic]
        df = df.append(df1)

# %%
df
# Out:
#                                   AIC      BIC
# PCA dim=2                     216.449  221.599
# PCA dim=3                     195.701  203.425
# PCA dim=4                     195.721   206.02
# PCA dim=5                     194.607  207.481
# LocallyLinearEmbedding dim=2  262.312  267.461
# LocallyLinearEmbedding dim=3  262.649  270.373
# LocallyLinearEmbedding dim=4  263.259  273.557
# LocallyLinearEmbedding dim=5  263.452  276.326
# MDS dim=2                     217.545  222.694
# MDS dim=3                     195.767  203.491
# MDS dim=4                     194.596  204.895
# MDS dim=5                     197.391  210.265
# SpectralEmbedding dim=2        215.72  220.869
# SpectralEmbedding dim=3       216.127  223.851
# SpectralEmbedding dim=4       217.997  228.296
# SpectralEmbedding dim=5       218.366   231.24
# TSNE dim=2                    269.739  274.888
# TSNE dim=3                     276.38  284.104
# TSNE dim=4                    261.725  272.024
# TSNE dim=5                    279.761  292.634

# %%
print ('Best w.r.t AIC -', np.argmin(df['AIC']))
print('Best w.r.t BIC -' , np.argmin(df['BIC']))
# Out:
# Best w.r.t AIC - MDS dim=4
# Best w.r.t BIC - PCA dim=3
